# %% [markdown]
# # FFNN Models

# %% [markdown]
# ## Basic Model

# %%
import yaml

from trainer.FFNN_model_trainer import FFNNModelTrainer 


# Load config
with open("./configs/FNN_basic.yml", encoding="utf-8") as f:
    config = yaml.safe_load(f)

# Model
ffnn_basic = FFNNModelTrainer(config)
# Out:
# Model loaded to  cuda

# %%
# Predict
some_text =  "قال علي  مرحبا بالجميع"
result = ffnn_basic.diactrize(some_text)

print(result)
# Out:
# قال علي  مَرحبا بالَجَميع

# %% [markdown]
# ## 100-Hot Model
